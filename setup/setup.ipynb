# %%
print('hello')
# Out:
# hello

# %%
# !git clone git@github.com:amanzoni1/new_project_deep.git
# Out:
# Cloning into 'new_project_deep'...
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git add .
# !git commit -m "Your commit message"
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
1+1
# Out:
# 2

# %%
import torch

if torch.cuda.is_available():
    print("Using CUDA (GPU)")
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
else:
    print("Using CPU")
# Out:
# Using CUDA (GPU)
# Device Name: Tesla T4

# %%
tensor = torch.rand(2, 3, 4)
print("Random Tensor:\n", tensor)
# Out:
# Random Tensor:
#  tensor([[[0.7953, 0.9212, 0.9951, 0.3028],
#          [0.7644, 0.7438, 0.1255, 0.2763],
#          [0.1571, 0.6790, 0.3047, 0.9114]],
#
#         [[0.1285, 0.7268, 0.2279, 0.9076],
#          [0.4653, 0.4239, 0.1359, 0.6504],
#          [0.5848, 0.9930, 0.6112, 0.7603]]])

# %%
tensor.shape
# Out:
# torch.Size([2, 3, 4])

# %%
# %config Completer.use_jedi = False

# %%
def prov():
  print('hello')

# %%
prov()
# Out:
# hello

# %%
tensor.max()
# Out:
# tensor(0.9951)

# %%
a = tensor

# %%
a
# Out:
# tensor([[[0.7953, 0.9212, 0.9951, 0.3028],
#          [0.7644, 0.7438, 0.1255, 0.2763],
#          [0.1571, 0.6790, 0.3047, 0.9114]],
#
#         [[0.1285, 0.7268, 0.2279, 0.9076],
#          [0.4653, 0.4239, 0.1359, 0.6504],
#          [0.5848, 0.9930, 0.6112, 0.7603]]])

# %%
tensor + a
# Out:
# tensor([[[1.5906, 1.8424, 1.9903, 0.6055],
#          [1.5289, 1.4876, 0.2510, 0.5526],
#          [0.3142, 1.3581, 0.6094, 1.8228]],
#
#         [[0.2570, 1.4536, 0.4557, 1.8153],
#          [0.9306, 0.8478, 0.2718, 1.3008],
#          [1.1697, 1.9860, 1.2223, 1.5206]]])
